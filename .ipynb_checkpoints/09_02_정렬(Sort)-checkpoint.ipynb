# %% [markdown]
# # 정렬 (Sort)
# ---
#
# ![sort](https://docs.tibco.com/pub/sfire-bauthor/7.5.0/doc/html/ko-KR/GUID-38D24175-9A0A-4A2B-A603-FC02F72AA8DB-display.png)
#
# - `어떤 기준`에 의해 값을 정렬
#     - ex: `오름차순` 기준이라면 값이 작은게 우선순위가 높고, 큰게 뒤로 간다
#     - ex: `내림차순` 기준이라면 값이 큰게 우선순위가 높고, 큰게 뒤로 간다

# %% [markdown]
# ---
# ## sort(), sorted()
# - sort() : 원본 변경
# - sorted() : 대상 변경 없이, 정렬된 결과 리턴
#
# ※위 정렬 함수는 `Timsort` 라는 정렬 알고리즘 사용

# %%
import random
myList = [
    
    random.randrange(1, 1000)
    for i in range(1000)
    
]


#myList

# %%
myList.sort()  # myList 원본을 변화시킴

# %%
myList[0:20]
# Out:
# [6, 7, 8, 9, 9, 11, 11, 11, 13, 14, 14, 15, 15, 16, 16, 20, 21, 23, 24, 25]

# %%
random.shuffle(myList)
myList[0:20]
# Out:
# [902,
#  675,
#  924,
#  437,
#  825,
#  282,
#  689,
#  365,
#  630,
#  632,
#  66,
#  842,
#  683,
#  726,
#  43,
#  72,
#  291,
#  683,
#  79,
#  375]

# %%
sorted(myList)  # 정렬된 결과를 리턴하는 함수, 원본은 변화 안시킴.
# Out:
# [6,
#  7,
#  8,
#  9,
#  9,
#  11,
#  11,
#  11,
#  13,
#  14,
#  14,
#  15,
#  15,
#  16,
#  16,
#  20,
#  21,
#  23,
#  24,
#  25,
#  25,
#  26,
#  28,
#  29,
#  31,
#  31,
#  31,
#  31,
#  32,
#  34,
#  35,
#  36,
#  37,
#  37,
#  38,
#  39,
#  40,
#  43,
#  43,
#  43,
#  43,
#  47,
#  47,
#  49,
#  51,
#  52,
#  53,
#  54,
#  55,
#  55,
#  57,
#  58,
#  58,
#  59,
#  59,
#  59,
#  61,
#  62,
#  62,
#  64,
#  66,
#  66,
#  68,
#  68,
#  69,
#  72,
#  73,
#  74,
#  75,
#  75,
#  76,
#  77,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  83,
#  83,
#  84,
#  84,
#  86,
#  87,
#  87,
#  87,
#  88,
#  88,
#  90,
#  94,
#  95,
#  95,
#  96,
#  96,
#  96,
#  97,
#  98,
#  99,
#  100,
#  100,
#  103,
#  103,
#  103,
#  107,
#  109,
#  109,
#  110,
#  111,
#  114,
#  114,
#  114,
#  115,
#  116,
#  116,
#  116,
#  117,
#  117,
#  117,
#  118,
#  120,
#  120,
#  122,
#  124,
#  125,
#  126,
#  126,
#  130,
#  131,
#  131,
#  131,
#  134,
#  135,
#  135,
#  135,
#  136,
#  136,
#  140,
#  140,
#  142,
#  144,
#  145,
#  145,
#  146,
#  147,
#  147,
#  149,
#  149,
#  149,
#  149,
#  152,
#  153,
#  153,
#  155,
#  155,
#  155,
#  155,
#  156,
#  158,
#  158,
#  159,
#  159,
#  161,
#  163,
#  163,
#  163,
#  163,
#  164,
#  164,
#  164,
#  169,
#  170,
#  170,
#  171,
#  172,
#  173,
#  174,
#  174,
#  175,
#  175,
#  176,
#  182,
#  182,
#  183,
#  183,
#  183,
#  184,
#  184,
#  185,
#  187,
#  188,
#  189,
#  190,
#  192,
#  192,
#  193,
#  193,
#  194,
#  196,
#  196,
#  196,
#  200,
#  203,
#  204,
#  206,
#  206,
#  207,
#  207,
#  208,
#  211,
#  212,
#  216,
#  219,
#  219,
#  221,
#  221,
#  222,
#  222,
#  224,
#  225,
#  227,
#  232,
#  232,
#  233,
#  235,
#  236,
#  236,
#  236,
#  238,
#  238,
#  238,
#  239,
#  243,
#  244,
#  245,
#  245,
#  246,
#  246,
#  246,
#  247,
#  248,
#  249,
#  250,
#  250,
#  255,
#  255,
#  256,
#  256,
#  256,
#  258,
#  258,
#  261,
#  262,
#  265,
#  265,
#  265,
#  270,
#  271,
#  272,
#  272,
#  273,
#  273,
#  273,
#  274,
#  274,
#  276,
#  277,
#  278,
#  279,
#  280,
#  280,
#  280,
#  280,
#  282,
#  282,
#  284,
#  284,
#  284,
#  285,
#  286,
#  287,
#  287,
#  288,
#  288,
#  289,
#  289,
#  290,
#  290,
#  291,
#  292,
#  294,
#  294,
#  296,
#  297,
#  297,
#  297,
#  297,
#  299,
#  301,
#  301,
#  301,
#  302,
#  303,
#  307,
#  308,
#  311,
#  312,
#  313,
#  313,
#  314,
#  314,
#  314,
#  317,
#  317,
#  318,
#  319,
#  320,
#  322,
#  326,
#  326,
#  326,
#  327,
#  328,
#  328,
#  330,
#  331,
#  332,
#  332,
#  334,
#  334,
#  335,
#  335,
#  335,
#  335,
#  336,
#  336,
#  337,
#  338,
#  338,
#  338,
#  339,
#  339,
#  340,
#  340,
#  341,
#  342,
#  343,
#  345,
#  345,
#  345,
#  345,
#  346,
#  346,
#  347,
#  349,
#  349,
#  349,
#  349,
#  349,
#  352,
#  353,
#  353,
#  353,
#  354,
#  356,
#  356,
#  357,
#  357,
#  359,
#  361,
#  361,
#  362,
#  365,
#  365,
#  371,
#  371,
#  374,
#  374,
#  375,
#  376,
#  377,
#  382,
#  382,
#  383,
#  384,
#  384,
#  384,
#  385,
#  386,
#  387,
#  388,
#  388,
#  388,
#  388,
#  388,
#  388,
#  389,
#  391,
#  392,
#  393,
#  394,
#  394,
#  396,
#  397,
#  397,
#  399,
#  400,
#  401,
#  405,
#  406,
#  406,
#  407,
#  407,
#  409,
#  409,
#  410,
#  412,
#  412,
#  414,
#  415,
#  416,
#  417,
#  417,
#  419,
#  422,
#  422,
#  427,
#  429,
#  430,
#  430,
#  431,
#  432,
#  434,
#  434,
#  435,
#  436,
#  437,
#  438,
#  439,
#  440,
#  441,
#  442,
#  442,
#  443,
#  445,
#  448,
#  448,
#  449,
#  450,
#  451,
#  452,
#  453,
#  455,
#  456,
#  458,
#  460,
#  461,
#  461,
#  461,
#  462,
#  464,
#  465,
#  467,
#  468,
#  469,
#  470,
#  472,
#  473,
#  476,
#  476,
#  476,
#  477,
#  477,
#  477,
#  478,
#  481,
#  481,
#  481,
#  487,
#  488,
#  489,
#  489,
#  489,
#  490,
#  492,
#  492,
#  494,
#  495,
#  496,
#  497,
#  497,
#  499,
#  500,
#  501,
#  503,
#  503,
#  503,
#  504,
#  504,
#  504,
#  505,
#  505,
#  507,
#  508,
#  509,
#  512,
#  513,
#  515,
#  515,
#  515,
#  515,
#  516,
#  517,
#  517,
#  518,
#  518,
#  518,
#  518,
#  522,
#  522,
#  522,
#  524,
#  524,
#  527,
#  528,
#  529,
#  530,
#  532,
#  533,
#  534,
#  535,
#  536,
#  537,
#  537,
#  538,
#  538,
#  539,
#  539,
#  540,
#  543,
#  545,
#  545,
#  546,
#  546,
#  548,
#  549,
#  549,
#  549,
#  549,
#  551,
#  551,
#  552,
#  552,
#  553,
#  553,
#  556,
#  556,
#  557,
#  558,
#  561,
#  562,
#  563,
#  565,
#  566,
#  567,
#  569,
#  571,
#  571,
#  573,
#  573,
#  574,
#  574,
#  575,
#  576,
#  576,
#  578,
#  579,
#  580,
#  580,
#  582,
#  583,
#  583,
#  585,
#  586,
#  587,
#  588,
#  588,
#  589,
#  590,
#  591,
#  594,
#  597,
#  597,
#  598,
#  599,
#  600,
#  601,
#  601,
#  605,
#  608,
#  608,
#  609,
#  609,
#  612,
#  612,
#  612,
#  613,
#  614,
#  615,
#  615,
#  617,
#  618,
#  618,
#  619,
#  620,
#  620,
#  620,
#  620,
#  620,
#  620,
#  621,
#  624,
#  624,
#  625,
#  625,
#  625,
#  625,
#  626,
#  626,
#  627,
#  627,
#  629,
#  630,
#  630,
#  631,
#  631,
#  632,
#  632,
#  635,
#  636,
#  636,
#  638,
#  640,
#  641,
#  642,
#  644,
#  645,
#  645,
#  646,
#  648,
#  649,
#  649,
#  651,
#  651,
#  651,
#  651,
#  652,
#  656,
#  657,
#  660,
#  661,
#  664,
#  665,
#  666,
#  668,
#  670,
#  671,
#  673,
#  673,
#  675,
#  676,
#  678,
#  680,
#  680,
#  680,
#  683,
#  683,
#  683,
#  684,
#  684,
#  685,
#  685,
#  689,
#  689,
#  689,
#  689,
#  689,
#  690,
#  690,
#  691,
#  694,
#  694,
#  694,
#  696,
#  696,
#  698,
#  699,
#  702,
#  703,
#  705,
#  707,
#  707,
#  707,
#  709,
#  709,
#  710,
#  710,
#  710,
#  711,
#  711,
#  711,
#  714,
#  716,
#  716,
#  716,
#  717,
#  718,
#  718,
#  719,
#  720,
#  720,
#  721,
#  721,
#  721,
#  722,
#  724,
#  726,
#  726,
#  726,
#  726,
#  729,
#  730,
#  733,
#  733,
#  733,
#  734,
#  735,
#  735,
#  739,
#  740,
#  742,
#  742,
#  744,
#  744,
#  745,
#  745,
#  746,
#  747,
#  748,
#  748,
#  749,
#  752,
#  752,
#  756,
#  757,
#  758,
#  758,
#  759,
#  761,
#  762,
#  764,
#  766,
#  766,
#  766,
#  766,
#  768,
#  768,
#  769,
#  770,
#  772,
#  774,
#  775,
#  776,
#  776,
#  777,
#  778,
#  779,
#  779,
#  779,
#  781,
#  781,
#  784,
#  784,
#  785,
#  786,
#  787,
#  788,
#  789,
#  789,
#  789,
#  791,
#  792,
#  793,
#  795,
#  795,
#  796,
#  799,
#  800,
#  801,
#  802,
#  802,
#  802,
#  806,
#  807,
#  808,
#  808,
#  808,
#  809,
#  810,
#  811,
#  813,
#  815,
#  815,
#  816,
#  817,
#  822,
#  822,
#  822,
#  824,
#  824,
#  825,
#  826,
#  826,
#  829,
#  829,
#  829,
#  830,
#  831,
#  832,
#  832,
#  833,
#  835,
#  837,
#  837,
#  838,
#  839,
#  840,
#  840,
#  841,
#  842,
#  846,
#  847,
#  848,
#  848,
#  848,
#  848,
#  850,
#  851,
#  853,
#  853,
#  854,
#  854,
#  854,
#  855,
#  855,
#  857,
#  857,
#  859,
#  860,
#  863,
#  864,
#  867,
#  867,
#  867,
#  868,
#  870,
#  870,
#  872,
#  872,
#  873,
#  873,
#  874,
#  878,
#  880,
#  880,
#  881,
#  882,
#  883,
#  884,
#  886,
#  887,
#  887,
#  889,
#  890,
#  890,
#  890,
#  892,
#  892,
#  894,
#  894,
#  896,
#  897,
#  897,
#  898,
#  898,
#  901,
#  902,
#  903,
#  905,
#  905,
#  907,
#  907,
#  908,
#  909,
#  910,
#  912,
#  912,
#  913,
#  914,
#  917,
#  918,
#  920,
#  923,
#  924,
#  924,
#  925,
#  925,
#  925,
#  925,
#  927,
#  928,
#  929,
#  929,
#  929,
#  930,
#  931,
#  931,
#  931,
#  932,
#  932,
#  932,
#  934,
#  934,
#  934,
#  936,
#  939,
#  939,
#  940,
#  940,
#  943,
#  945,
#  946,
#  949,
#  950,
#  951,
#  952,
#  953,
#  954,
#  955,
#  957,
#  958,
#  960,
#  962,
#  962,
#  962,
#  963,
#  964,
#  964,
#  964,
#  965,
#  967,
#  967,
#  968,
#  970,
#  971,
#  971,
#  971,
#  972,
#  973,
#  973,
#  973,
#  974,
#  975,
#  976,
#  978,
#  979,
#  980,
#  981,
#  981,
#  982,
#  982,
#  983,
#  984,
#  984,
#  985,
#  985,
#  986,
#  987,
#  987,
#  987,
#  988,
#  989,
#  989,
#  990,
#  995,
#  995,
#  996,
#  996,
#  997,
#  998,
#  999]

# %%
myList
# Out:
# [902,
#  675,
#  924,
#  437,
#  825,
#  282,
#  689,
#  365,
#  630,
#  632,
#  66,
#  842,
#  683,
#  726,
#  43,
#  72,
#  291,
#  683,
#  79,
#  375,
#  297,
#  58,
#  193,
#  517,
#  284,
#  9,
#  100,
#  939,
#  416,
#  507,
#  374,
#  410,
#  580,
#  496,
#  77,
#  573,
#  172,
#  43,
#  854,
#  729,
#  792,
#  694,
#  347,
#  896,
#  492,
#  912,
#  665,
#  853,
#  666,
#  690,
#  117,
#  586,
#  631,
#  385,
#  545,
#  461,
#  274,
#  338,
#  353,
#  196,
#  116,
#  985,
#  788,
#  173,
#  130,
#  388,
#  601,
#  894,
#  583,
#  503,
#  860,
#  341,
#  887,
#  776,
#  696,
#  857,
#  400,
#  361,
#  597,
#  256,
#  332,
#  384,
#  79,
#  680,
#  327,
#  890,
#  439,
#  546,
#  600,
#  134,
#  442,
#  265,
#  857,
#  590,
#  898,
#  711,
#  273,
#  640,
#  158,
#  53,
#  886,
#  605,
#  136,
#  835,
#  449,
#  689,
#  826,
#  907,
#  99,
#  359,
#  787,
#  719,
#  430,
#  51,
#  769,
#  998,
#  746,
#  870,
#  838,
#  972,
#  822,
#  356,
#  192,
#  34,
#  710,
#  932,
#  58,
#  508,
#  489,
#  853,
#  726,
#  710,
#  100,
#  974,
#  735,
#  775,
#  432,
#  772,
#  16,
#  824,
#  75,
#  227,
#  245,
#  518,
#  702,
#  118,
#  336,
#  660,
#  382,
#  464,
#  170,
#  388,
#  762,
#  975,
#  159,
#  436,
#  793,
#  353,
#  733,
#  934,
#  489,
#  407,
#  374,
#  931,
#  745,
#  311,
#  95,
#  709,
#  349,
#  748,
#  176,
#  55,
#  31,
#  250,
#  720,
#  256,
#  892,
#  120,
#  613,
#  38,
#  777,
#  37,
#  864,
#  934,
#  995,
#  822,
#  54,
#  31,
#  288,
#  338,
#  340,
#  207,
#  870,
#  435,
#  409,
#  963,
#  74,
#  515,
#  903,
#  312,
#  55,
#  749,
#  294,
#  910,
#  881,
#  995,
#  778,
#  971,
#  448,
#  982,
#  24,
#  955,
#  996,
#  962,
#  236,
#  406,
#  925,
#  430,
#  225,
#  569,
#  651,
#  841,
#  540,
#  518,
#  349,
#  636,
#  943,
#  190,
#  206,
#  458,
#  609,
#  349,
#  307,
#  537,
#  953,
#  159,
#  276,
#  566,
#  31,
#  965,
#  238,
#  183,
#  158,
#  887,
#  377,
#  11,
#  620,
#  59,
#  476,
#  393,
#  518,
#  673,
#  440,
#  280,
#  277,
#  939,
#  103,
#  690,
#  664,
#  499,
#  621,
#  802,
#  909,
#  505,
#  676,
#  962,
#  492,
#  314,
#  625,
#  314,
#  556,
#  580,
#  768,
#  145,
#  290,
#  107,
#  745,
#  563,
#  768,
#  536,
#  462,
#  183,
#  184,
#  441,
#  710,
#  337,
#  714,
#  270,
#  200,
#  149,
#  625,
#  680,
#  826,
#  61,
#  142,
#  726,
#  964,
#  561,
#  184,
#  867,
#  476,
#  116,
#  781,
#  147,
#  694,
#  20,
#  786,
#  206,
#  618,
#  932,
#  951,
#  352,
#  59,
#  68,
#  553,
#  545,
#  641,
#  588,
#  301,
#  346,
#  524,
#  156,
#  388,
#  255,
#  642,
#  280,
#  678,
#  221,
#  296,
#  756,
#  88,
#  161,
#  272,
#  78,
#  47,
#  925,
#  389,
#  807,
#  109,
#  553,
#  707,
#  779,
#  630,
#  504,
#  967,
#  83,
#  244,
#  539,
#  175,
#  848,
#  822,
#  952,
#  552,
#  131,
#  837,
#  37,
#  512,
#  626,
#  451,
#  246,
#  219,
#  742,
#  238,
#  549,
#  354,
#  417,
#  32,
#  832,
#  957,
#  517,
#  721,
#  125,
#  971,
#  465,
#  808,
#  14,
#  299,
#  164,
#  170,
#  759,
#  847,
#  585,
#  779,
#  135,
#  810,
#  448,
#  832,
#  817,
#  594,
#  632,
#  962,
#  718,
#  894,
#  23,
#  147,
#  204,
#  196,
#  94,
#  880,
#  705,
#  301,
#  757,
#  985,
#  691,
#  533,
#  503,
#  802,
#  87,
#  461,
#  274,
#  271,
#  233,
#  583,
#  785,
#  976,
#  16,
#  651,
#  744,
#  417,
#  287,
#  707,
#  711,
#  934,
#  978,
#  537,
#  313,
#  837,
#  194,
#  136,
#  211,
#  86,
#  830,
#  207,
#  620,
#  362,
#  461,
#  405,
#  431,
#  371,
#  80,
#  163,
#  551,
#  718,
#  117,
#  848,
#  120,
#  25,
#  636,
#  601,
#  434,
#  670,
#  261,
#  301,
#  460,
#  598,
#  987,
#  619,
#  155,
#  809,
#  920,
#  964,
#  335,
#  273,
#  811,
#  90,
#  387,
#  320,
#  683,
#  144,
#  615,
#  627,
#  717,
#  289,
#  40,
#  319,
#  833,
#  289,
#  334,
#  808,
#  349,
#  646,
#  331,
#  707,
#  549,
#  612,
#  401,
#  69,
#  625,
#  984,
#  392,
#  126,
#  163,
#  535,
#  356,
#  279,
#  265,
#  648,
#  897,
#  238,
#  735,
#  840,
#  174,
#  481,
#  487,
#  612,
#  522,
#  365,
#  699,
#  996,
#  353,
#  243,
#  850,
#  651,
#  532,
#  345,
#  649,
#  800,
#  981,
#  490,
#  47,
#  627,
#  913,
#  443,
#  384,
#  982,
#  889,
#  854,
#  661,
#  872,
#  565,
#  322,
#  789,
#  95,
#  282,
#  808,
#  549,
#  620,
#  829,
#  673,
#  152,
#  556,
#  450,
#  936,
#  335,
#  624,
#  317,
#  488,
#  739,
#  419,
#  212,
#  733,
#  986,
#  530,
#  824,
#  744,
#  684,
#  256,
#  626,
#  429,
#  292,
#  126,
#  878,
#  394,
#  188,
#  907,
#  111,
#  929,
#  764,
#  829,
#  84,
#  388,
#  326,
#  297,
#  558,
#  193,
#  651,
#  467,
#  116,
#  399,
#  973,
#  383,
#  468,
#  979,
#  883,
#  781,
#  680,
#  973,
#  685,
#  932,
#  131,
#  855,
#  255,
#  930,
#  272,
#  155,
#  618,
#  872,
#  335,
#  39,
#  445,
#  551,
#  75,
#  80,
#  538,
#  890,
#  571,
#  608,
#  422,
#  931,
#  396,
#  689,
#  415,
#  495,
#  989,
#  766,
#  163,
#  397,
#  62,
#  98,
#  645,
#  806,
#  758,
#  232,
#  988,
#  456,
#  21,
#  960,
#  285,
#  573,
#  567,
#  815,
#  970,
#  64,
#  905,
#  182,
#  391,
#  730,
#  88,
#  971,
#  689,
#  522,
#  287,
#  615,
#  258,
#  867,
#  905,
#  153,
#  303,
#  776,
#  140,
#  709,
#  288,
#  924,
#  795,
#  114,
#  49,
#  752,
#  515,
#  339,
#  114,
#  848,
#  422,
#  831,
#  13,
#  925,
#  290,
#  571,
#  854,
#  587,
#  509,
#  617,
#  987,
#  874,
#  901,
#  855,
#  149,
#  548,
#  624,
#  631,
#  990,
#  409,
#  863,
#  59,
#  629,
#  472,
#  950,
#  155,
#  720,
#  384,
#  774,
#  579,
#  726,
#  29,
#  153,
#  345,
#  668,
#  867,
#  543,
#  620,
#  224,
#  135,
#  528,
#  171,
#  515,
#  721,
#  918,
#  500,
#  14,
#  52,
#  799,
#  208,
#  967,
#  884,
#  908,
#  175,
#  505,
#  318,
#  169,
#  716,
#  923,
#  928,
#  222,
#  989,
#  247,
#  766,
#  349,
#  187,
#  345,
#  524,
#  388,
#  612,
#  115,
#  131,
#  671,
#  122,
#  469,
#  638,
#  912,
#  868,
#  816,
#  83,
#  314,
#  694,
#  929,
#  326,
#  76,
#  62,
#  232,
#  733,
#  689,
#  284,
#  284,
#  114,
#  980,
#  397,
#  394,
#  174,
#  286,
#  591,
#  497,
#  155,
#  249,
#  427,
#  740,
#  784,
#  239,
#  574,
#  246,
#  789,
#  973,
#  476,
#  722,
#  552,
#  294,
#  987,
#  477,
#  335,
#  330,
#  716,
#  724,
#  258,
#  557,
#  576,
#  685,
#  66,
#  11,
#  546,
#  326,
#  36,
#  110,
#  504,
#  761,
#  578,
#  929,
#  721,
#  97,
#  880,
#  43,
#  839,
#  684,
#  758,
#  752,
#  84,
#  954,
#  574,
#  747,
#  890,
#  265,
#  25,
#  984,
#  917,
#  518,
#  332,
#  317,
#  489,
#  248,
#  124,
#  477,
#  235,
#  164,
#  68,
#  280,
#  766,
#  236,
#  31,
#  371,
#  497,
#  802,
#  840,
#  236,
#  297,
#  222,
#  278,
#  182,
#  96,
#  455,
#  388,
#  949,
#  791,
#  620,
#  80,
#  582,
#  620,
#  795,
#  645,
#  15,
#  262,
#  28,
#  848,
#  163,
#  501,
#  407,
#  481,
#  873,
#  26,
#  412,
#  434,
#  851,
#  164,
#  8,
#  504,
#  361,
#  748,
#  898,
#  73,
#  340,
#  35,
#  406,
#  696,
#  185,
#  357,
#  597,
#  192,
#  644,
#  549,
#  376,
#  882,
#  334,
#  529,
#  575,
#  414,
#  742,
#  250,
#  784,
#  140,
#  599,
#  412,
#  386,
#  302,
#  635,
#  892,
#  339,
#  576,
#  513,
#  940,
#  87,
#  7,
#  470,
#  117,
#  859,
#  246,
#  914,
#  608,
#  57,
#  6,
#  698,
#  452,
#  357,
#  481,
#  614,
#  503,
#  345,
#  328,
#  964,
#  103,
#  342,
#  815,
#  927,
#  657,
#  829,
#  494,
#  280,
#  589,
#  796,
#  522,
#  149,
#  983,
#  183,
#  245,
#  473,
#  273,
#  931,
#  734,
#  203,
#  478,
#  789,
#  981,
#  9,
#  11,
#  146,
#  221,
#  779,
#  711,
#  477,
#  313,
#  219,
#  196,
#  453,
#  96,
#  145,
#  945,
#  338,
#  968,
#  43,
#  109,
#  716,
#  801,
#  343,
#  103,
#  534,
#  135,
#  813,
#  15,
#  308,
#  346,
#  149,
#  515,
#  96,
#  656,
#  438,
#  649,
#  873,
#  538,
#  539,
#  703,
#  442,
#  946,
#  846,
#  897,
#  328,
#  940,
#  609,
#  336,
#  588,
#  516,
#  189,
#  999,
#  997,
#  562,
#  925,
#  527,
#  297,
#  625,
#  766,
#  382,
#  652,
#  770,
#  216,
#  958,
#  87]

# %% [markdown]
# # 정렬 알고리즘의 성능
# time complexity 는 다음 3가지로 귀결
#
# 1. **O(*n*<sup>2</sup>)**  <-- worst
# 1. **O(*n* log *n*)**    <-- average
# 1. **O(*n*)**          <-- impossible?
#
# > 특정 정렬 알고리즘의 성능이 항상 고정되어 있지 않다.   정렬하는 데이터의 분포 나 형태에 따라 성능이 달라질수 있다.     따라서,  각 알고리즘을 정확히 이해하고, 구현할줄 알며, 각각의 특성에 따라 어떠한 데이터 상황에서 정렬에 유리한지 알아야 한다.

# %% [markdown]
# # 다양한 정렬 알고리즘
#
# https://www.toptal.com/developers/sorting-algorithms  (시각화, 비교)
#
# ![sort](http://www.webappers.com/img/2009/04/sorting-algorithm.jpg)
#
#
# # 알고리즘 시각화 사이트
#
# https://visualgo.net/ko
#
# http://sorting.at/#

# %% [markdown]
# # 정렬및 검색 알고리즘 학습시..
#
# - 각 알고리즘에 대한 이해
# - 각 동작 사이클마다 값의 변화 (ex: 정렬상태의 변화)
# - 각 알고리즘의 성능에 대한 이해
#     - **best case** VS **worst case**
