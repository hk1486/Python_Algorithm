# %%
print('Hello Jupyter')
print('Hello Python')
print('안녕하세요')
# Out:
# Hello Jupyter
# Hello Python
# 안녕하세요

# %%
100
# Out:
# 100

# %%
100 * 2
# Out:
# 200

# %%
print(100)
# Out:
# 100

# %%
print(100 * 2)
# Out:
# 200

# %%
# command mode
# edit mode

# edit mode 에서 command mode로 전환시 단축키 esc
# shift + enter 누르면 코드 실행


# command -> edit mode 전환시 클릭 혹은 enter  

# command 단축키
# b : 셀 추가 (아래로)
# a : 셀 추가 (위로)
# x : 셀 삭제
# y : --> Code 셀로 변환
# m : --> Markdown 셀로 변환
# 1~5 : 제목 1~5 단계
# ctrl + s : 저장

# %% [markdown]
# 마크다운 문서(메모)

# %%
100

300
# Out:
# 300

# %%
200

# %%
400

# %% [markdown]
# # 제목 1단계

# %% [markdown]
# ## 제목 2단계

# %% [markdown]
# ### 제목3단계
# #### 제목 4단계
# ##### 제목 5단계
# 제목1 - 6단계

# %%
while True:
    print('aaa')
# Out:
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# aaa
# ...
